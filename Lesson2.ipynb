# %% [markdown]
# <a href="https://colab.research.google.com/github/Terry18-coder/Pulse254/blob/main/Lesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5+11
# Out:
# 16

# %%
6+9
# Out:
# 15

# %% [markdown]
# Python addition

# %%
6-2
# Out:
# 4

# %% [markdown]
# #DATA TYPES

# %%
#NUMBERS
#INTEGERS  POSITIVE WHOLE NUMBERS,NEGATIVE WHOLE NUMBERS AND ZEROS
#FLOATS   DECIMAL NUMBERS

# %%
6
# Out:
# 6

# %%
type(6)
# Out:
# int

# %%
type(6.0)
# Out:
# float

# %%
#STRING

# %%
#BOOL
